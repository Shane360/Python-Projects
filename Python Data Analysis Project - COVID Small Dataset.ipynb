# %% [markdown]
# # COVID-19 Small Dataset

# %%
import pandas as pd
import numpy as np

# %%
covid_data = pd.read_csv("C:/Users/User/Documents/Tech/Python/Tutorials/Python Portfolio Project Tuts/Data Science Lovers Project Tuts/Covid_Data.csv")
covid_data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
covid_data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
# Find out if Null values present in df

covid_data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as PercentFormatter
import seaborn as sns

sns.set()

# %%
# Use heatmap to show the null values
sns.heatmap(covid_data.isnull())
plt.show()

# %% [markdown]
# # 1. Show Number of Confirmed deaths and recovery cases in each Region

# %%
covid_data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
# df.groupby('Region').sum().head(50)
# df.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(20)
# df.groupby('Region')['Confirmed'], 'Recovered'].sum()

covid_data.groupby('Region').sum().head()
# Out:
#                   Date State  Confirmed  Deaths  Recovered
# Region
# Afghanistan  4/29/2020     0       1939      60        252
# Albania      4/29/2020     0        766      30        455
# Algeria      4/29/2020     0       3848     444       1702
# Andorra      4/29/2020     0        743      42        423
# Angola       4/29/2020     0         27       2          7

# %%
# Sort confirmed from highest to lowest

covid_data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False)
# Out:
# Region
# US                       1039909
# Spain                     236899
# Italy                     203591
# France                    166543
# UK                        166441
#                           ...
# Sao Tome and Principe          8
# Papua New Guinea               8
# Bhutan                         7
# Western Sahara                 6
# Yemen                          6
# Name: Confirmed, Length: 187, dtype: int64

# %%
# Sort from lowest to highest

covid_data.groupby('Region')['Confirmed'].sum().sort_values(ascending = True)
# Out:
# Region
# Yemen                          6
# Western Sahara                 6
# Bhutan                         7
# Papua New Guinea               8
# Sao Tome and Principe          8
#                           ...
# UK                        166441
# France                    166543
# Italy                     203591
# Spain                     236899
# US                       1039909
# Name: Confirmed, Length: 187, dtype: int64

# %%
# Remember to use [[double brackets]] when filtering by multiple columns after goruping by Region, if not it will throw an error


covid_data.groupby('Region')[['Confirmed', 'Recovered']].sum()
# Out:
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %% [markdown]
# # 2. Remove all the records where Confirmed cases is Less than 10

# %%
# df.Confirmed < 10
# df[df.Confirmed < 10]
# df[~(df.Confirmed < 10)]
# df = df[~(df.Confirmed < 10)]

# %%
covid_data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
covid_data[~(covid_data.Confirmed < 10)]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
covid_data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
covid_data = covid_data[~(covid_data.Confirmed < 10)]

# %%
covid_data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %% [markdown]
# # 3. In which region is the maximum number of confirmed cases recorded?

# %%
# df.groupby('Region')['Confirmed'].sum().sort_values(ascending = False)


covid_data.head(3)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702

# %%
covid_data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False)
# Out:
# Region
# US            1039909
# Spain          236899
# Italy          203591
# France         166536
# UK             166432
#                ...
# Seychelles         11
# Burundi            11
# Suriname           10
# Gambia             10
# Holy See           10
# Name: Confirmed, Length: 180, dtype: int64

# %%
covid_data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(10)          # TOp 10 maximum
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166536
# UK                 166432
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82861
# Name: Confirmed, dtype: int64

# %% [markdown]
# # 4. In which region is the minimum number of confirmed cases recorded?

# %%
covid_data.head(4)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423

# %%
covid_data.groupby('Region')['Confirmed'].sum().sort_values(ascending = True)
# Out:
# Region
# Suriname           10
# Gambia             10
# Holy See           10
# Burundi            11
# Seychelles         11
#                ...
# UK             166432
# France         166536
# Italy          203591
# Spain          236899
# US            1039909
# Name: Confirmed, Length: 180, dtype: int64

# %%
# Top 10 minimum values

covid_data.groupby('Region')['Confirmed'].sum().sort_values(ascending = True).head(10)
# Out:
# Region
# Suriname                            10
# Gambia                              10
# Holy See                            10
# Burundi                             11
# Seychelles                          11
# Nicaragua                           13
# Saint Kitts and Nevis               15
# Dominica                            16
# Namibia                             16
# Saint Vincent and the Grenadines    16
# Name: Confirmed, dtype: int64

# %% [markdown]
# # 5. How many confirmed deaths and recovered cases were reported from India till April 29, 2020

# %%
# df[df.Region == 'country_name']

covid_data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
covid_data[covid_data.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
covid_data[covid_data.Region == 'Albania']
# Out:
#         Date State   Region  Confirmed  Deaths  Recovered
# 1  4/29/2020   NaN  Albania        766      30        455

# %%
covid_data[covid_data.Region == 'US'].head(10)
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
#
#      Recovered
# 181          0
# 182          0
# 186          0
# 187          0
# 195          0
# 199          0
# 200          0
# 202          0
# 204          0
# 205          0

# %% [markdown]
# # 6. Sort entire Data with respect to number of Confirmed cases in ascending order

# %%
# df.sort_values(by = ['Confirmed'], ascending = True)

covid_data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
covid_data.sort_values(by = ['Confirmed'], ascending = True).head(10)
# Out:
#           Date                     State      Region  Confirmed  Deaths  \
# 156  4/29/2020                       NaN    Suriname         10       1
# 70   4/29/2020                       NaN    Holy See         10       0
# 59   4/29/2020                       NaN      Gambia         10       1
# 318  4/29/2020                     Yukon      Canada         11       0
# 217  4/29/2020                 Greenland     Denmark         11       0
# 256  4/29/2020                Montserrat          UK         11       1
# 144  4/29/2020                       NaN  Seychelles         11       0
# 27   4/29/2020                       NaN     Burundi         11       1
# 306  4/29/2020  Turks and Caicos Islands          UK         12       1
# 118  4/29/2020                       NaN   Nicaragua         13       3
#
#      Recovered
# 156          8
# 70           2
# 59           8
# 318          0
# 217         11
# 256          2
# 144          6
# 27           4
# 306          5
# ...

# %% [markdown]
# # 7. Sort entire Data with respect to number of Confirmed cases in descending order

# %%
covid_data.sort_values(by = ['Confirmed'], ascending = False).head(10)
# Out:
#           Date       State   Region  Confirmed  Deaths  Recovered
# 265  4/29/2020    New York       US     299691   23477          0
# 153  4/29/2020         NaN    Spain     236899   24275     132929
# 80   4/29/2020         NaN    Italy     203591   27682      71252
# 168  4/29/2020         NaN       UK     165221   26097          0
# 57   4/29/2020         NaN   France     165093   24087      48228
# 61   4/29/2020         NaN  Germany     161539    6467     120400
# 167  4/29/2020         NaN   Turkey     117589    3081      44040
# 262  4/29/2020  New Jersey       US     116365    6771          0
# 134  4/29/2020         NaN   Russia      99399     972      10286
# 76   4/29/2020         NaN     Iran      93657    5957      73791
